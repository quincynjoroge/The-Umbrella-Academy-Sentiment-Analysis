# %% [markdown]
# ## Pull Comments

# %%
import googleapiclient.discovery
import googleapiclient.errors

api_service_name = "youtube"
api_version = "v3"
DEVELOPER_KEY = "AIzaSyB58vPq5HOGA4iH8FAp4kyYGLO5ZafPc5Y"

youtube = googleapiclient.discovery.build(
    api_service_name, api_version, developerKey=DEVELOPER_KEY)

request = youtube.commentThreads().list(
    part="snippet",
    videoId="1Oktfn1k-5M",
    maxResults=1000
)
response = request.execute()

for item in response['items']:
    print(item['snippet']['topLevelComment']['snippet']['textDisplay'])

# %% [markdown]
# ## Output as Pandas DataFrame

# %%
import googleapiclient.discovery
import pandas as pd

api_service_name = "youtube"
api_version = "v3"
DEVELOPER_KEY = "AIzaSyB58vPq5HOGA4iH8FAp4kyYGLO5ZafPc5Y"

youtube = googleapiclient.discovery.build(
    api_service_name, api_version, developerKey=DEVELOPER_KEY)

request = youtube.commentThreads().list(
    part="snippet",
    videoId="1Oktfn1k-5M",
    maxResults=1000
)
response = request.execute()

comments = []

for item in response['items']:
    comment = item['snippet']['topLevelComment']['snippet']
    comments.append([
        comment['authorDisplayName'],
        comment['publishedAt'],
        comment['updatedAt'],
        comment['likeCount'],
        comment['textDisplay']
    ])

# Paginate through additional pages
while 'nextPageToken' in response:
    next_page_token = response['nextPageToken']
    request = youtube.commentThreads().list(
        part="snippet",
        videoId="1Oktfn1k-5M",
        maxResults=1000,
        pageToken=next_page_token
    )
    response = request.execute()

    # Process comments on this page
    for item in response['items']:
        comment = item['snippet']['topLevelComment']['snippet']
        comments.append([
            comment['authorDisplayName'],
            comment['publishedAt'],
            comment['updatedAt'],
            comment['likeCount'],
            comment['textDisplay']
        ])


df = pd.DataFrame(comments, columns=['author', 'published_at', 'updated_at', 'like_count', 'text'])

df
# Out:
#              author          published_at            updated_at  like_count  \
# 0      CrakaBakBlak  2021-09-25T16:54:08Z  2021-09-25T16:56:53Z           1
# 1       Clyde Dango  2021-05-31T21:32:39Z  2021-05-31T21:32:39Z           2
# 2     Izzy Martinez  2021-05-17T07:00:41Z  2021-05-17T07:00:41Z           1
# 3     Robert Taylor  2020-12-26T12:22:32Z  2020-12-26T12:22:32Z           0
# 4    TheAceOfSpades  2020-12-12T22:32:43Z  2020-12-12T22:32:43Z           0
# ..              ...                   ...                   ...         ...
# 331      PartyMcFly  2019-02-16T00:35:28Z  2019-02-16T00:35:28Z          23
# 332     Krayboolius  2019-02-16T00:33:18Z  2019-02-16T00:33:18Z           1
# 333      Matt Firth  2019-02-16T00:32:02Z  2019-02-16T00:32:02Z           0
# 334           tre e  2019-02-16T00:31:44Z  2019-02-16T00:31:44Z           5
# 335             jar  2019-02-16T00:31:07Z  2019-02-16T00:31:07Z         512
#
#                                                   text
# ...

# %%
df.shape
# Out:
# (336, 5)

# %%
df.to_csv('Season 1yt.csv',index=False)

# %%
import googleapiclient.discovery
import pandas as pd

api_service_name = "youtube"
api_version = "v3"
DEVELOPER_KEY = "AIzaSyB58vPq5HOGA4iH8FAp4kyYGLO5ZafPc5Y"

youtube = googleapiclient.discovery.build(
    api_service_name, api_version, developerKey=DEVELOPER_KEY)

request = youtube.commentThreads().list(
    part="snippet",
    videoId="ik9HJJ2HdB8",
    maxResults=1000
)
response = request.execute()

comments = []

for item in response['items']:
    comment = item['snippet']['topLevelComment']['snippet']
    comments.append([
        comment['authorDisplayName'],
        comment['publishedAt'],
        comment['updatedAt'],
        comment['likeCount'],
        comment['textDisplay']
    ])

# Paginate through additional pages
while 'nextPageToken' in response:
    next_page_token = response['nextPageToken']
    request = youtube.commentThreads().list(
        part="snippet",
        videoId="ik9HJJ2HdB8",
        maxResults=1000,
        pageToken=next_page_token
    )
    response = request.execute()

    # Process comments on this page
    for item in response['items']:
        comment = item['snippet']['topLevelComment']['snippet']
        comments.append([
            comment['authorDisplayName'],
            comment['publishedAt'],
            comment['updatedAt'],
            comment['likeCount'],
            comment['textDisplay']
        ])


df = pd.DataFrame(comments, columns=['author', 'published_at', 'updated_at', 'like_count', 'text'])

df
# Out:
#                      author          published_at            updated_at  \
# 0            Let Me Explain  2020-08-12T08:25:25Z  2020-08-12T08:25:25Z
# 1     The Overnight Results  2023-07-24T04:34:28Z  2023-07-24T04:34:28Z
# 2       RidingAShoppingCart  2023-06-28T00:13:14Z  2023-06-28T00:13:14Z
# 3                  Empty 09  2023-06-09T09:17:28Z  2023-06-09T09:17:28Z
# 4              kodymodywody  2023-06-02T22:21:27Z  2023-06-02T22:21:27Z
# ...                     ...                   ...                   ...
# 1029        speakingofzaaii  2020-08-12T15:02:28Z  2020-08-12T15:02:28Z
# 1030           Megan Turney  2020-08-12T15:02:14Z  2020-08-12T15:02:14Z
# 1031             PinkSweets  2020-08-12T15:02:03Z  2020-08-12T15:02:03Z
# 1032            frostyheaux  2020-08-12T15:01:33Z  2020-08-12T15:01:33Z
# 1033                 Almond  2020-08-12T15:00:56Z  2020-08-12T15:00:56Z
#
#       like_count                                               text
# ...

# %%
df.to_csv('Season 2yt.csv',index=False)

# %%
import googleapiclient.discovery
import pandas as pd

api_service_name = "youtube"
api_version = "v3"
DEVELOPER_KEY = "AIzaSyB58vPq5HOGA4iH8FAp4kyYGLO5ZafPc5Y"

youtube = googleapiclient.discovery.build(
    api_service_name, api_version, developerKey=DEVELOPER_KEY)

request = youtube.commentThreads().list(
    part="snippet",
    videoId="NoQ-rdqGDfk",
    maxResults=2000
)
response = request.execute()

comments = []

for item in response['items']:
    comment = item['snippet']['topLevelComment']['snippet']
    comments.append([
        comment['authorDisplayName'],
        comment['publishedAt'],
        comment['updatedAt'],
        comment['likeCount'],
        comment['textDisplay']
    ])

# Paginate through additional pages
while 'nextPageToken' in response:
    next_page_token = response['nextPageToken']
    request = youtube.commentThreads().list(
        part="snippet",
        videoId="NoQ-rdqGDfk",
        maxResults=2000,
        pageToken=next_page_token
    )
    response = request.execute()

    # Process comments on this page
    for item in response['items']:
        comment = item['snippet']['topLevelComment']['snippet']
        comments.append([
            comment['authorDisplayName'],
            comment['publishedAt'],
            comment['updatedAt'],
            comment['likeCount'],
            comment['textDisplay']
        ])


df = pd.DataFrame(comments, columns=['author', 'published_at', 'updated_at', 'like_count', 'text'])

df
# Out:
#                        author          published_at            updated_at  \
# 0              Heavy Spoilers  2022-06-25T06:05:00Z  2022-06-25T06:05:00Z
# 1           Callum Withington  2023-08-15T22:05:18Z  2023-08-15T22:05:18Z
# 2                     oolong2  2023-07-26T04:50:40Z  2023-07-26T04:50:40Z
# 3     El Goblino The Protogen  2023-07-16T16:22:50Z  2023-07-16T16:22:50Z
# 4      Toasted Synapse Gaming  2023-07-01T22:25:34Z  2023-07-01T22:25:34Z
# ...                       ...                   ...                   ...
# 1283            Sophia Tomlin  2022-06-25T14:03:04Z  2022-06-25T14:03:04Z
# 1284            Saikath Ghosh  2022-06-25T14:03:02Z  2022-06-25T14:03:02Z
# 1285                      F Z  2022-06-25T14:02:59Z  2022-06-25T14:02:59Z
# 1286                Dani Dyke  2022-06-25T14:02:50Z  2022-06-25T14:02:50Z
# 1287     The Spider Scientist  2022-06-25T14:02:38Z  2022-06-25T14:02:38Z
#
#       like_count                                               text
# ...

# %%
df.to_csv("Season 3yt.csv",index=False)
